# %%
import requests

# %%
import bs4

# %%
result = requests.get("https://sk.wikipedia.org/wiki/Elon_Musk")

# %%
type(result)
# Out:
# requests.models.Response

# %%
result.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-toc-available" lang="sk" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Elon Musk – Wikipédia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-wi
# ...

# %%
import bs4

# %%
soup = bs4.BeautifulSoup(result.text, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-toc-available" dir="ltr" lang="sk">
# <head>
# <meta charset="utf-8"/>
# <title>Elon Musk – Wikipédia</title>
# ...

# %%
soup.select('title')[0].getText()
# Out:
# 'Elon Musk – Wikipédia'

# %%
site_paragraphs = soup.select('p')

# %%
site_paragraphs[0].getText()
# Out:
# 'Elon Reeve Musk, FRS (* 28. jún 1971, Pretória) je podnikateľ, investor a filantrop. Je zakladateľom, predsedom, generálnym riaditeľom a technickým riaditeľom spoločnosti SpaceX, anjelským investorom, generálnym riaditeľom, produktovým architektom a bývalým predsedom firmy Tesla, Inc., majiteľom, predsedom a technickým riaditeľom X Corp. (ktorá prevádzkuje sociálnu sieť X, predtým známu ako Twitter), zakladateľom The Boring Company a xAI, spoluzakladateľom Neuralinku a OpenAI a prezidentom filantropickej nadácie Musk Foundation. Podľa Bloomberg Billionaires Index a rebríčka Real Time Billionaires časopisu Forbes bol Elon Musk v decembri 2023 najbohatším človekom na svete, a to najmä vďaka vlastníckym podielom v spoločnostiach Tesla a SpaceX, pričom jeho čistý majetok sa podľa Bloombergu odhaduje na približne 232 miliárd dolárov a podľa Forbesu na 254 miliárd dolárov.[1][2][3]\n'

# %%
soup.select('.vector-dropdown')
# Out:
# [<div class="vector-dropdown vector-main-menu-dropdown vector-button-flush-left vector-button-flush-right" id="vector-main-menu-dropdown">
#  <input aria-haspopup="true" aria-label="Hlavní menu" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-main-menu-dropdown" id="vector-main-menu-dropdown-checkbox" role="button" type="checkbox"/>
#  <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-main-menu-dropdown-checkbox" id="vector-main-menu-dropdown-label"><span class="vector-icon mw-ui-icon-menu mw-ui-icon-wikimedia-menu"></span>
#  <span class="vector-dropdown-label-text">Hlavní menu</span>
#  </label>
#  <div class="vector-dropdown-content">
#  <div class="vector-unpinned-container" id="vector-main-menu-unpinned-container">
#  <div class="vector-main-menu vector-pinnable-element" id="vector-main-menu">
# ...

# %%
first_item = soup.select('.vector-dropdown')[0]

# %%
for item in soup.select('.vector-dropdown'):
    print(item.text)
# Out:
# Hlavní menu
#
#
#
#
#
# Hlavní menu
# přesunout do postranního panelu
# skryť
#
#
#
# 		Navigácia
#
#
#
# Hlavná stránkaPortál komunityKaviareňPosledné úpravyNáhodná stránkaPomocníkPrispieť
#
#
#
#
#
# Jazyky
#
# Tu na Wikipédia sú jazykové odkazy vpravo hore vedľa názvu článku. Ísť hore.
#
#
#
#
#
#
#
#
#
#
# Osobné nástroje
#
#
#
#
#
#  Vytvoriť účet Prihlásiť sa
#
#
#
#
#
# 		Stránky pre odhlásených redaktorov zistiť viac
#
#
#
# PríspevkyDiskusia
#
#
#
#
#
#
#
#
# Prepnúť obsah
#
#
#
#
#
#
#
#
#
# 142 jazykov
#
#
#
#
# ...

# %%
response = requests.get("https://sk.wikipedia.org/wiki/Airbus_A340")

# %%
soup = bs4.BeautifulSoup(response.text,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-toc-available" dir="ltr" lang="sk">
# <head>
# <meta charset="utf-8"/>
# <title>Airbus A340 – Wikipédia</title>
# ...

# %%
soup.select('img')
# Out:
# [<img alt="" aria-hidden="true" class="mw-logo-icon" height="50" src="/static/images/icons/wikipedia.png" width="50"/>,
#  <img alt="Wikipédia" class="mw-logo-wordmark" src="/static/images/mobile/copyright/wikipedia-wordmark-fr.svg" style="width: 7.5em; height: 1.125em;"/>,
#  <img alt="Slobodná encyklopédia" class="mw-logo-tagline" height="13" src="/static/images/mobile/copyright/wikipedia-tagline-sk.svg" style="width: 7.375em; height: 0.8125em;" width="118"/>,
#  <img class="mw-file-element" data-file-height="2848" data-file-width="4288" decoding="async" height="199" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/87/F-GLZH_CDG_%2846671826914%29.jpg/300px-F-GLZH_CDG_%2846671826914%29.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/87/F-GLZH_CDG_%2846671826914%29.jpg/450px-F-GLZH_CDG_%2846671826914%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/87/F-GLZH_CDG_%2846671826914%29.jpg/600px-F-GLZH_CDG_%2846671826914%29.jpg 2x" width="300"/>,
# ...

# %%
img = soup.select('img')[4]

# %%
img
# Out:
# <img alt="Letecký portál" class="mw-file-element" data-file-height="700" data-file-width="650" decoding="async" height="19" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/00/Avion_silhouette.svg/18px-Avion_silhouette.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/00/Avion_silhouette.svg/27px-Avion_silhouette.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/00/Avion_silhouette.svg/36px-Avion_silhouette.svg.png 2x" width="18"/>

# %%
img['src']
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/0/00/Avion_silhouette.svg/18px-Avion_silhouette.svg.png'

# %% [markdown]
# <img src='//upload.wikimedia.org/wikipedia/commons/thumb/0/00/Avion_silhouette.svg/18px-Avion_silhouette.svg.png' />

# %%
image_link = requests.get('https://upload.wikimedia.org/wikipedia/commons/thumb/8/87/F-GLZH_CDG_%2846671826914%29.jpg/300px-F-GLZH_CDG_%2846671826914%29.jpg')

# %%
image_link.content
# Out:
# b'\xff\xd8\xff\xe2\x02\x1cICC_PROFILE\x00\x01\x01\x00\x00\x02\x0clcms\x02\x10\x00\x00mntrRGB XYZ \x07\xdc\x00\x01\x00\x19\x00\x03\x00)\x009acspAPPL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-lcms\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\ndesc\x00\x00\x00\xfc\x00\x00\x00^cprt\x00\x00\x01\\\x00\x00\x00\x0bwtpt\x00\x00\x01h\x00\x00\x00\x14bkpt\x00\x00\x01|\x00\x00\x00\x14rXYZ\x00\x00\x01\x90\x00\x00\x00\x14gXYZ\x00\x00\x01\xa4\x00\x00\x00\x14bXYZ\x00\x00\x01\xb8\x00\x00\x00\x14rTRC\x00\x00\x01\xcc\x00\x00\x00@gTRC\x00\x00\x01\xcc\x00\x00\x00@bTRC\x00\x00\x01\xcc\x00\x00\x00@desc\x00\x00\x00\x00\x00\x00\x00\x03c2\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x
# ...

# %%
f = open('my_computer_image.jpg', 'wb')

# %%
f.write(image_link.content)
# Out:
# 12684

# %%
f.close()
